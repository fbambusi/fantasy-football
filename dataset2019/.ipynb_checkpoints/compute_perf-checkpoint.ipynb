# %%
import pandas as pd

# %%
players=pd.read_csv("Quotazioni_Fantacalcio.csv")

# %%
print(players.count())
# Out:
# Id         570
# R          570
# Name       570
# Squadra    570
# Qt. A      570
# Qt. I      570
# Diff.      570
# dtype: int64

# %%
print(players.columns.values)
print(players.dtypes)
# Out:
# ['Id' 'R' 'Name' 'Squadra' 'Qt. A' 'Qt. I' 'Diff.']
# Id          int64
# R          object
# Name       object
# Squadra    object
# Qt. A       int64
# Qt. I       int64
# Diff.       int64
# dtype: object

# %%
my_synthesis=pd.read_csv("players_synthesis_by_me.csv")
my_synthesis=my_synthesis.drop_duplicates(subset='Name', keep='first')
print(my_synthesis.columns.values)
print(my_synthesis.dtypes)
print(my_synthesis.count())
# Out:
# ['Unnamed: 0' 'Name' 'VarianceFantasyEvaluation' 'PlayedMatches' 'Team'
#  'Role' 'MedianFantasyEvaluation' 'WeightedFantasyEvaluation' 'Qt..A'
#  'Qt..I' 'Plays2018_2019' 'Owner' 'Price' 'MantraRole'
#  'MeanFantasyEvaluation']
# Unnamed: 0                     int64
# Name                          object
# VarianceFantasyEvaluation    float64
# PlayedMatches                  int64
# Team                          object
# Role                          object
# MedianFantasyEvaluation      float64
# WeightedFantasyEvaluation    float64
# Qt..A                          int64
# Qt..I                          int64
# Plays2018_2019               float64
# Owner                         object
# Price                        float64
# MantraRole                    object
# MeanFantasyEvaluation        float64
# dtype: object
# Unnamed: 0                   444
# Name                         444
# VarianceFantasyEvaluation    332
# PlayedMatches                444
# Team                         346
# Role                         444
# MedianFantasyEvaluation      346
# WeightedFantasyEvaluation    444
# Qt..A                        444
# Qt..I                        444
# Plays2018_2019                 0
# Owner                         86
# Price                         84
# MantraRole                   444
# MeanFantasyEvaluation        444
# dtype: int64

# %%
pls=pd.merge(my_synthesis, players, left_on='Name', right_on='Name',how="right")
print(pls.columns.values)
print(pls.count())
# Out:
# ['Unnamed: 0' 'Name' 'VarianceFantasyEvaluation' 'PlayedMatches' 'Team'
#  'Role' 'MedianFantasyEvaluation' 'WeightedFantasyEvaluation' 'Qt..A'
#  'Qt..I' 'Plays2018_2019' 'Owner' 'Price' 'MantraRole'
#  'MeanFantasyEvaluation' 'Id' 'R' 'Squadra' 'Qt. A' 'Qt. I' 'Diff.']
# Unnamed: 0                   324
# Name                         570
# VarianceFantasyEvaluation    254
# PlayedMatches                324
# Team                         260
# Role                         324
# MedianFantasyEvaluation      260
# WeightedFantasyEvaluation    324
# Qt..A                        324
# Qt..I                        324
# Plays2018_2019                 0
# Owner                         72
# Price                         70
# MantraRole                   324
# MeanFantasyEvaluation        324
# Id                           570
# R                            570
# Squadra                      570
# Qt. A                        570
# Qt. I                        570
# Diff.                        570
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
attackers=pls[pls['Role']=="A"]
X = pls[["Qt. A","WeightedFantasyEvaluation"]]
X=X.dropna()
y = X["WeightedFantasyEvaluation"]
X=X.drop("WeightedFantasyEvaluation",axis=1)

reg = LinearRegression().fit(X**0.5, y)
print(reg.score(X, y))

x = np.linspace(0,10,1000)
y2 = reg.intercept_+reg.coef_[0]*x

plt.scatter(X["Qt. A"]**0.5,y)
plt.plot(x,y2)
plt.show()
'''Probably best model for outliers (interesting players)'''
# Out:
# -23.432764557302
# 'Probably best model for outliers (interesting players)'

# %%
pls_with_no_mean=pls[pls['MeanFantasyEvaluation'].isnull()]
print(pls_with_no_mean)
# Out:
#      Unnamed: 0                Name  VarianceFantasyEvaluation  PlayedMatches  \
# 324         NaN            LUKAKU R                        NaN            NaN
# 325         NaN         RAFAEL LEAO                        NaN            NaN
# 326         NaN              LOZANO                        NaN            NaN
# 327         NaN              RIBERY                        NaN            NaN
# 328         NaN              MURIEL                        NaN            NaN
# 329         NaN           BALOTELLI                        NaN            NaN
# 330         NaN              RAMSEY                        NaN            NaN
# 331         NaN                RUIZ                        NaN            NaN
# 332         NaN       DONNARUMMA AL                        NaN            NaN
# 333         NaN             ZANIOLO                        NaN            NaN
# 334         NaN        ANDRE' SILVA                        NaN            NaN
# 335         NaN               GODIN                        NaN            NaN
# 336         NaN             DE LIGT                        NaN            NaN
# 337         NaN              RABIOT                        NaN            NaN
# 338         NaN            PAQUETA'                        NaN            NaN
# 339         NaN           PAU LOPEZ                        NaN            NaN
# 340         NaN           SANSONE N                        NaN            NaN
# 341         NaN         TORREGROSSA                        NaN            NaN
# 342         NaN          GABBIADINI                        NaN            NaN
# 343         NaN          DI CARMINE                        NaN            NaN
# 344         NaN               KUCKA                        NaN            NaN
# 345         NaN             KARAMOH                        NaN            NaN
# 346         NaN         MALINOVSKYI                        NaN            NaN
# 347         NaN              SCHONE                        NaN            NaN
# 348         NaN               MUSSO                        NaN            NaN
# 349         NaN              OBIANG                        NaN            NaN
# 350         NaN              NANDEZ                        NaN            NaN
# 351         NaN            SANABRIA                        NaN            NaN
# 352         NaN         NESTOROVSKI                        NaN            NaN
# 353         NaN             PAZZINI                        NaN            NaN
# ..          ...                 ...                        ...            ...
# 540         NaN           VIVIANI M                        NaN            NaN
# 541         NaN          COLOMBATTO                        NaN            NaN
# 542         NaN             MONTIEL                        NaN            NaN
# 543         NaN             ROVELLA                        NaN            NaN
# 544         NaN             ZENNARO                        NaN            NaN
# 545         NaN              AGOUME                        NaN            NaN
# 546         NaN             FAGIOLI                        NaN            NaN
# 547         NaN  NICOLUSSI CAVIGLIA                        NaN            NaN
# 548         NaN           PORTANOVA                        NaN            NaN
# 549         NaN             GAETANO                        NaN            NaN
# 550         NaN              MACHIN                        NaN            NaN
# 551         NaN            RICCARDI                        NaN            NaN
# 552         NaN           STREFEZZA                        NaN            NaN
# 553         NaN          DE ANGELIS                        NaN            NaN
# 554         NaN           COULIBALY                        NaN            NaN
# 555         NaN       LUCAS FELIPPE                        NaN            NaN
# 556         NaN           CAMBIAGHI                        NaN            NaN
# 557         NaN             PICCOLI                        NaN            NaN
# 558         NaN              JUWARA                        NaN            NaN
# 559         NaN         ESPOSITO SE                        NaN            NaN
# 560         NaN           SALCEDO E                        NaN            NaN
# 561         NaN            ADORANTE                        NaN            NaN
# 562         NaN              BARAYE                        NaN            NaN
# 563         NaN            CANGIANO                        NaN            NaN
# 564         NaN            BAHLOULI                        NaN            NaN
# 564  NaN  NaN                      NaN                        NaN    NaN
# 565  NaN  NaN                      NaN                        NaN    NaN
# 566  NaN  NaN                      NaN                        NaN    NaN
# 567  NaN  NaN                      NaN                        NaN    NaN
# 568  NaN  NaN                      NaN                        NaN    NaN
# 569  NaN  NaN                      NaN                        NaN    NaN
#
#      Qt..I  ...  Owner Price  MantraRole MeanFantasyEvaluation    Id  R  \
# 324    NaN  ...    NaN   NaN         NaN                   NaN  2531  A
# 325    NaN  ...    NaN   NaN         NaN                   NaN  4510  A
# 326    NaN  ...    NaN   NaN         NaN                   NaN  4517  A
# 327    NaN  ...    NaN   NaN         NaN                   NaN  2409  C
# 328    NaN  ...    NaN   NaN         NaN                   NaN   507  A
# 329    NaN  ...    NaN   NaN         NaN                   NaN   696  A
# 330    NaN  ...    NaN   NaN         NaN                   NaN  2472  C
# 331    NaN  ...    NaN   NaN         NaN                   NaN  2775  C
# 332    NaN  ...    NaN   NaN         NaN                   NaN  4452  A
# 333    NaN  ...    NaN   NaN         NaN                   NaN  2766  C
# 334    NaN  ...    NaN   NaN         NaN                   NaN  2175  A
# 335    NaN  ...    NaN   NaN         NaN                   NaN  2572  D
# 336    NaN  ...    NaN   NaN         NaN                   NaN  4428  D
# 337    NaN  ...    NaN   NaN         NaN                   NaN  2379  C
# 338    NaN  ...    NaN   NaN         NaN                   NaN  4322  C
# 339    NaN  ...    NaN   NaN         NaN                   NaN  4419  P
# 340    NaN  ...    NaN   NaN         NaN                   NaN   537  A
# 341    NaN  ...    NaN   NaN         NaN                   NaN  4453  A
# 342    NaN  ...    NaN   NaN         NaN                   NaN   407  A
# 343    NaN  ...    NaN   NaN         NaN                   NaN  4500  A
# 344    NaN  ...    NaN   NaN         NaN                   NaN   234  C
# 345    NaN  ...    NaN   NaN         NaN                   NaN  2325  A
# 346    NaN  ...    NaN   NaN         NaN                   NaN  4427  C
# 347    NaN  ...    NaN   NaN         NaN                   NaN  4512  C
# 348    NaN  ...    NaN   NaN         NaN                   NaN  2792  P
# 349    NaN  ...    NaN   NaN         NaN                   NaN  4501  C
# 350    NaN  ...    NaN   NaN         NaN                   NaN  4514  C
# 351    NaN  ...    NaN   NaN         NaN                   NaN   479  A
# 352    NaN  ...    NaN   NaN         NaN                   NaN  1943  A
# 353    NaN  ...    NaN   NaN         NaN                   NaN   636  A
# ..     ...  ...    ...   ...         ...                   ...   ... ..
# 540    NaN  ...    NaN   NaN         NaN                   NaN  4451  C
# 541    NaN  ...    NaN   NaN         NaN                   NaN  2828  C
# 542    NaN  ...    NaN   NaN         NaN                   NaN  4353  C
# 543    NaN  ...    NaN   NaN         NaN                   NaN  4459  C
# 544    NaN  ...    NaN   NaN         NaN                   NaN  4383  C
# 545    NaN  ...    NaN   NaN         NaN                   NaN  4411  C
# 546    NaN  ...    NaN   NaN         NaN                   NaN  4465  C
# 547    NaN  ...    NaN   NaN         NaN                   NaN  4349  C
# 548    NaN  ...    NaN   NaN         NaN                   NaN  4370  C
# 549    NaN  ...    NaN   NaN         NaN                   NaN  4364  C
# 550    NaN  ...    NaN   NaN         NaN                   NaN   666  C
# 551    NaN  ...    NaN   NaN         NaN                   NaN  2852  C
# 552    NaN  ...    NaN   NaN         NaN                   NaN  4486  C
# 553    NaN  ...    NaN   NaN         NaN                   NaN  4490  C
# 554    NaN  ...    NaN   NaN         NaN                   NaN  2144  C
# 555    NaN  ...    NaN   NaN         NaN                   NaN  4499  C
# 556    NaN  ...    NaN   NaN         NaN                   NaN  4436  A
# 557    NaN  ...    NaN   NaN         NaN                   NaN  4359  A
# 558    NaN  ...    NaN   NaN         NaN                   NaN  4368  A
# 559    NaN  ...    NaN   NaN         NaN                   NaN  4463  A
# 560    NaN  ...    NaN   NaN         NaN                   NaN  2304  A
# 561    NaN  ...    NaN   NaN         NaN                   NaN  4387  A
# 562    NaN  ...    NaN   NaN         NaN                   NaN  2805  A
# 563    NaN  ...    NaN   NaN         NaN                   NaN  4483  A
# 564    NaN  ...    NaN   NaN         NaN                   NaN  4508  A
# 565    NaN  ...    NaN   NaN         NaN                   NaN  4371  A
# 566    NaN  ...    NaN   NaN         NaN                   NaN  4346  A
# 567    NaN  ...    NaN   NaN         NaN                   NaN  4489  A
# 568    NaN  ...    NaN   NaN         NaN                   NaN  2794  A
# 569    NaN  ...    NaN   NaN         NaN                   NaN   767  A
#
#         Squadra Qt. A  Qt. I  Diff.
# 324       Inter    36     35      1
# 325       Milan    22     22      0
# 326      Napoli    22     22      0
# 327  Fiorentina    19     19      0
# 328    Atalanta    19     17      2
# 329     Brescia    19     19      0
# 330    Juventus    18     18      0
# 331      Napoli    17     17      0
# 332     Brescia    17     16      1
# 333        Roma    16     16      0
# 334       Milan    15     15      0
# 335       Inter    14     14      0
# 336    Juventus    14     14      0
# 337    Juventus    14     14      0
# 338       Milan    14     15     -1
# 339        Roma    13     14     -1
# 340     Bologna    13     12      1
# 341     Brescia    13     13      0
# 342   Sampdoria    13     13      0
# 343      Verona    13     13      0
# 344       Parma    12     12      0
# 345       Parma    12     12      0
# 346    Atalanta    11     11      0
# 347       Genoa    11     11      0
# 348     Udinese    10      9      1
# 349    Sassuolo    10     10      0
# 350    Cagliari    10     10      0
# 351       Genoa    10     10      0
# 352     Udinese    10     10      0
# 353      Verona    10     10      0
# ..          ...   ...    ...    ...
# 540     Brescia     1      1      0
# 541    Cagliari     1      1      0
# 542  Fiorentina     1      1      0
# 543       Genoa     1      1      0
# 544       Genoa     1      1      0
# 545       Inter     1      1      0
# 546    Juventus     1      1      0
# 547    Juventus     1      1      0
# 548    Juventus     1      1      0
# 549      Napoli     1      1      0
# 550       Parma     1      1      0
# 551        Roma     1      1      0
# 552        SPAL     1      1      0
# 553      Torino     1      1      0
# 554     Udinese     1      1      0
# 555      Verona     1      1      0
# 556    Atalanta     1      1      0
# 557    Atalanta     1      1      0
# 558     Bologna     1      1      0
# 559       Inter     1      1      0
# 560       Inter     1      1      0
# 561       Parma     1      1      0
# 562       Parma     1      1      0
# 563     Bologna     1      1      0
# 564   Sampdoria     1      1      0
# 565    Sassuolo     1      1      0
# 566      Torino     1      1      0
# 567      Torino     1      1      0
# 568     Udinese     1      1      0
# 569      Verona     1      1      0
#
# [246 rows x 21 columns]
