# %%
import pandas as pd

# %%
players=pd.read_csv("Quotazioni_Fantacalcio_Ruoli_Mantra.csv")

# %%
players["Name"]=players["Name"].str.replace(" ","")
players["Name"]=players["Name"].str.replace("-","")
players["Name"]=players["Name"].str.replace("'","")

# %%
playersStats=pd.read_csv("Statistiche_Fantacalcio_2018-19.csv")
playersStats["Name"]=playersStats["Nome"].str.replace(" ","")
playersStats["Name"]=playersStats["Nome"].str.replace("-","")
playersStats["Name"]=playersStats["Nome"].str.replace("'","")

# %%
pls=pd.merge(playersStats, players, left_on='Name', right_on='Name',how="right")
print(pls.columns.values)
print(pls.count())
print(pls[pls["Name"]=="LUKAKU R"])
# Out:
# ['Id_x' 'R_x' 'Nome' 'Squadra_x' 'Pg' 'Mv' 'Mf' 'WeightedPerf' 'Name'
#  'Id_y' 'R_y' 'Squadra_y' 'Qt. A' 'Qt. I' 'Diff.']
# Id_x            346
# R_x             346
# Nome            346
# Squadra_x       346
# Pg              346
# Mv              346
# Mf              346
# WeightedPerf    346
# Name            570
# Id_y            570
# R_y             570
# Squadra_y       570
# Qt. A           570
# Qt. I           570
# Diff.           570
# dtype: int64
# Empty DataFrame
# Columns: [Id_x, R_x, Nome, Squadra_x, Pg, Mv, Mf, WeightedPerf, Name, Id_y, R_y, Squadra_y, Qt. A, Qt. I, Diff.]
# Index: []

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
X = pls[["Qt. A","WeightedPerf"]]
X=X.dropna()
y = X["WeightedPerf"]
X=X.drop("WeightedPerf",axis=1)

reg = LinearRegression().fit(X, y)
print(reg.score(X, y))

x = np.linspace(0,10,1000)
y2 = reg.intercept_+reg.coef_[0]*x

plt.scatter(X["Qt. A"],y)
plt.plot(x,y2)
plt.show()
'''Probably best model for outliers (interesting players)'''
# Out:
# 0.5176511329260343
# 'Probably best model for outliers (interesting players)'

# %%
pls_with_no_mean=pls[pls['WeightedPerf'].isnull()]
print(pls_with_no_mean.count())
print("\n\n")
print(pls.count())
# Out:
# Id_x              0
# R_x               0
# Nome              0
# Squadra_x         0
# Pg                0
# Mv                0
# Mf                0
# WeightedPerf      0
# Name            224
# Id_y            224
# R_y             224
# Squadra_y       224
# Qt. A           224
# Qt. I           224
# Diff.           224
# dtype: int64
#
#
#
# Id_x            346
# R_x             346
# Nome            346
# Squadra_x       346
# Pg              346
# Mv              346
# Mf              346
# WeightedPerf    346
# Name            570
# Id_y            570
# R_y             570
# Squadra_y       570
# Qt. A           570
# Qt. I           570
# Diff.           570
# dtype: int64

# %%
attrs=pls_with_no_mean[["WeightedPerf","Qt. A"]]
attrs=attrs.drop("WeightedPerf",axis=1)
pls_with_no_mean["WeightedPerf"]=reg.predict(attrs)
#print(pls_with_no_mean[["MeanFantasyEvaluation","Name"]])
print(pls_with_no_mean.count())
print(pls_with_no_mean)
# Out:
# Id_x              0
# R_x               0
# Nome              0
# Squadra_x         0
# Pg                0
# Mv                0
# Mf                0
# WeightedPerf    224
# Name            224
# Id_y            224
# R_y             224
# Squadra_y       224
# Qt. A           224
# Qt. I           224
# Diff.           224
# dtype: int64
#      Id_x  R_x Nome Squadra_x  Pg  Mv  Mf  WeightedPerf               Name  \
# 346   NaN  NaN  NaN       NaN NaN NaN NaN     11.032453   CRISTIANORONALDO
# 347   NaN  NaN  NaN       NaN NaN NaN NaN      9.061199            LUKAKUR
# 348   NaN  NaN  NaN       NaN NaN NaN NaN      8.842171            ZAPATAD
# 349   NaN  NaN  NaN       NaN NaN NaN NaN      6.870918             GOMEZA
# 350   NaN  NaN  NaN       NaN NaN NaN NaN      6.651890          MARTINEZL
# 351   NaN  NaN  NaN       NaN NaN NaN NaN      6.213833    MILINKOVICSAVIC
# 352   NaN  NaN  NaN       NaN NaN NaN NaN      5.994805             DEPAUL
# 353   NaN  NaN  NaN       NaN NaN NaN NaN      5.994805         RAFAELLEAO
# 354   NaN  NaN  NaN       NaN NaN NaN NaN      5.994805             LOZANO
# 355   NaN  NaN  NaN       NaN NaN NaN NaN      5.775777        LUISALBERTO
# 356   NaN  NaN  NaN       NaN NaN NaN NaN      5.775777         IAGOFALQUE
# 357   NaN  NaN  NaN       NaN NaN NaN NaN      5.337721             RIBERY
# 358   NaN  NaN  NaN       NaN NaN NaN NaN      5.337721          BALOTELLI
# 359   NaN  NaN  NaN       NaN NaN NaN NaN      5.118693             RAMSEY
# 360   NaN  NaN  NaN       NaN NaN NaN NaN      4.899665       DONNARUMMAAL
# 361   NaN  NaN  NaN       NaN NaN NaN NaN      4.680636          JOAOPEDRO
# 362   NaN  NaN  NaN       NaN NaN NaN NaN      4.461608        DONNARUMMAG
# 363   NaN  NaN  NaN       NaN NaN NaN NaN      4.461608           LAZZARIM
# 364   NaN  NaN  NaN       NaN NaN NaN NaN      4.461608         ANDRESILVA
# 365   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580              GODIN
# 366   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580         ALEXSANDRO
# 367   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580             DELIGT
# 368   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580         ROMAGNOLIA
# 369   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580           MANCINIG
# 370   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580                CAN
# 371   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580       DOUGLASCOSTA
# 372   NaN  NaN  NaN       NaN NaN NaN NaN      4.242580             RABIOT
# 373   NaN  NaN  NaN       NaN NaN NaN NaN      4.023552           PAULOPEZ
# 374   NaN  NaN  NaN       NaN NaN NaN NaN      4.023552             DEVRIJ
# 375   NaN  NaN  NaN       NaN NaN NaN NaN      4.023552       PELLEGRINILO
# ..    ...  ...  ...       ...  ..  ..  ..           ...                ...
# 540   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214             TERZIC
# 541   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214             RIZZON
# 542   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214              GALLO
# 543   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214          RICCARDID
# 544   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214             GABBIA
# 545   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214            MINELLI
# 546   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214              BOUAH
# 547   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214         BUONGIORNO
# 548   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214              GILLI
# 549   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214          CRESCENZI
# 550   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214           CIPRIANO
# 551   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214            COLLEYE
# 552   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214          TREMOLADA
# 553   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214           VIVIANIM
# 554   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214            ROVELLA
# 555   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214            ZENNARO
# 556   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214             AGOUME
# 557   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214            FAGIOLI
# 558   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214  NICOLUSSICAVIGLIA
# 559   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214          STREFEZZA
# 560   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214          DEANGELIS
# 561   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214       LUCASFELIPPE
# 562   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214          CAMBIAGHI
# 563   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214         ESPOSITOSE
# 564   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214           SALCEDOE
# 565   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214           ADORANTE
# 566   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214           CANGIANO
# 567   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214           BAHLOULI
# 568   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214              RAUTI
# 569   NaN  NaN  NaN       NaN NaN NaN NaN      1.395214              TUPTA
#
#      Id_y R_y   Squadra_y  Qt. A  Qt. I  Diff.
# 346  2610   A    Juventus     45     46     -1
# 347  2531   A       Inter     36     35      1
# 348   608   A    Atalanta     35     36     -1
# 349    26   C    Atalanta     26     26      0
# 350  2764   A       Inter     25     26     -1
# 351   645   C       Lazio     23     23      0
# 352  1996   C     Udinese     22     22      0
# 353  4510   A       Milan     22     22      0
# 354  4517   A      Napoli     22     22      0
# 355  2085   C       Lazio     21     20      1
# 356   475   A      Torino     21     21      0
# 357  2409   C  Fiorentina     19     19      0
# 358   696   A     Brescia     19     19      0
# 359  2472   C    Juventus     18     18      0
# 360  4452   A     Brescia     17     16      1
# 361  1874   A    Cagliari     16     16      0
# 362   350   P       Milan     15     15      0
# 363  2263   C       Lazio     15     15      0
# 364  2175   A       Milan     15     15      0
# 365  2572   D       Inter     14     14      0
# 366   662   D    Juventus     14     14      0
# 367  4428   D    Juventus     14     14      0
# 368   460   D       Milan     14     14      0
# 369  2296   D        Roma     14     14      0
# 370  2504   C    Juventus     14     14      0
# 371  2200   C    Juventus     14     14      0
# 372  2379   C    Juventus     14     14      0
# 373  4419   P        Roma     13     14     -1
# 374   322   D       Inter     13     13      0
# 375   530   C        Roma     13     13      0
# ..    ...  ..         ...    ...    ...    ...
# 540  4375   D  Fiorentina      1      1      0
# 541  4392   D       Genoa      1      1      0
# 542  4502   D       Lecce      1      1      0
# 543  4473   D       Lecce      1      1      0
# 544  4401   D       Milan      1      1      0
# 545  4480   D       Parma      1      1      0
# 546  4481   D        Roma      1      1      0
# 547  2724   D      Torino      1      1      0
# 548  4488   D      Torino      1      1      0
# 549   457   D      Verona      1      1      0
# 550  4509   D       Lazio      1      1      0
# 551  4435   C    Atalanta      1      1      0
# 552  4450   C     Brescia      1      1      0
# 553  4451   C     Brescia      1      1      0
# 554  4459   C       Genoa      1      1      0
# 555  4383   C       Genoa      1      1      0
# 556  4411   C       Inter      1      1      0
# 557  4465   C    Juventus      1      1      0
# 558  4349   C    Juventus      1      1      0
# 559  4486   C        SPAL      1      1      0
# 560  4490   C      Torino      1      1      0
# 561  4499   C      Verona      1      1      0
# 562  4436   A    Atalanta      1      1      0
# 563  4463   A       Inter      1      1      0
# 564  2304   A       Inter      1      1      0
# 565  4387   A       Parma      1      1      0
# 566  4483   A     Bologna      1      1      0
# 567  4508   A   Sampdoria      1      1      0
# 568  4489   A      Torino      1      1      0
# 569   767   A      Verona      1      1      0
#
# [224 rows x 15 columns]
# /home/asino/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pls_with_mean=pls[pls['WeightedPerf'].notnull()]
playerz=pd.concat([pls_with_mean,pls_with_no_mean],ignore_index=True)
print(playerz.count())
playerz.to_csv("players_with_interpolated_mean.csv")
# Out:
# Id_x            346
# R_x             346
# Nome            346
# Squadra_x       346
# Pg              346
# Mv              346
# Mf              346
# WeightedPerf    570
# Name            570
# Id_y            570
# R_y             570
# Squadra_y       570
# Qt. A           570
# Qt. I           570
# Diff.           570
# dtype: int64

# %%
from scipy.stats import binom
def probToPlay(playersInField,indexOfPlayer,probabilityOfFault):
    minNumberOfFaults=indexOfPlayer-playersInField
    probOfLessThanOrEqualNFaults=binom.cdf(minNumberOfFaults-1, playersInField, probabilityOfFault)
    return 1-probOfLessThanOrEqualNFaults
print(probToPlay(4,5,0.1))
# Out:
# 0.3439

# %%
def getPlayerRoleCompatibilityString():
    mantraRoles=pd.read_csv("Quotazioni_Fantacalcio_Ruoli_Mantra.csv")
    mantraRoles["Name"]=mantraRoles["Name"].str.replace(" ","")
    mantraRoles["Name"]=mantraRoles["Name"].str.replace("-","")
    mantraRoles["Name"]=mantraRoles["Name"].str.replace("'","")
    
    mantraRoles=pd.merge(mantraRoles, pls[["Name"]], left_on='Name', right_on='Name',how="inner")
    
    
    roleCompatibilityString = "set CompatibilityPlayerRole:= \n"
    for  index, player in mantraRoles.iterrows():
        roleCompatibilityString+= "({},*)".format(player["Name"])
        for role in player["R"].split(";"):
            roleCompatibilityString+=" {}".format(role)
        roleCompatibilityString+="\n"
    roleCompatibilityString+=";"
    return roleCompatibilityString

print(getPlayerRoleCompatibilityString())
# Out:
# set CompatibilityPlayerRole:=
# (CRISTIANORONALDO,*) Pc
# (PIATEK,*) Pc
# (IMMOBILE,*) Pc
# (LUKAKUR,*) Pc
# (ZAPATAD,*) Pc
# (QUAGLIARELLA,*) Pc
# (ICARDI,*) Pc
# (DZEKO,*) Pc
# (BELOTTI,*) Pc
# (INSIGNE,*) A
# (HIGUAIN,*) Pc
# (MERTENS,*) Pc
# (MILIK,*) Pc
# (CHIESA,*) W A
# (GOMEZA,*) T A
# (CAPUTO,*) Pc
# (PETAGNA,*) Pc
# (ILICIC,*) A
# (PAVOLETTI,*) Pc
# (MARTINEZL,*) Pc
# (DYBALA,*) A
# (INGLESE,*) Pc
# (MILINKOVICSAVIC,*) C T
# (DEPAUL,*) T A
# (RAFAELLEAO,*) Pc
# (IAGOFALQUE,*) A
# (LOZANO,*) A
# (MANDZUKIC,*) Pc
# (CORREA,*) A
# (BERNARDESCHI,*) W A
# (SUSO,*) W A
# (CALLEJON,*) W
# (LUISALBERTO,*) T
# (PINAMONTI,*) Pc
# (UNDER,*) W A
# (RIBERY,*) W A
# (MURIEL,*) Pc
# (BALOTELLI,*) Pc
# (GERVINHO,*) A
# (HANDANOVIC,*) Por
# (DESTRO,*) Pc
# (BARELLA,*) M C
# (BONAVENTURA,*) C W T
# (KOUAME,*) A
# (BERARDI,*) A
# (ORSOLINI,*) W A
# (VERDI,*) W A
# (KLUIVERT,*) W
# (RAMSEY,*) T
# (SZCZESNY,*) Por
# (DONNARUMMAAL,*) Pc
# (LAZZARIM,*) E
# (RUIZ,*) C T
# (BOATENG,*) A
# (ZANIOLO,*) T
# (LASAGNA,*) Pc
# (KOLAROV,*) Ds E
# (CRISCITO,*) Ds Dc E
# (IZZO,*) Dd Dc
# (NAINGGOLAN,*) C T
# (ZIELINSKI,*) C T
# (KURTIC,*) C T
# (JOAOPEDRO,*) A
# (DONNARUMMAG,*) Por
# (PULGAR,*) M C
# (CAN,*) M C
# (PAROLO,*) M C
# (ALLAN,*) M C
# (GOSENS,*) E
# (HATEBOER,*) E
# (ANSALDI,*) E
# (SKRINIAR,*) Dc
# (CHIELLINI,*) Dc
# (KOULIBALY,*) Dc
# (NKOULOU,*) Dc
# (PJANIC,*) C
# (DEFREL,*) A
# (POLITANO,*) W A
# (BOGA,*) W A
# (DOUGLASCOSTA,*) W
# (PEROTTI,*) W
# (PAQUETA,*) T
# (GOLLINI,*) Por
# (STRAKOSHA,*) Por
# (MERET,*) Por
# (SIRIGU,*) Por
# (BABACAR,*) Pc
# (KUCKA,*) M C
# (ALEXSANDRO,*) Ds E
# (GODIN,*) Dc
# (DELIGT,*) Dc
# (ACERBI,*) Dc
# (ROMAGNOLIA,*) Dc
# (MANCINIG,*) Dc
# (BENASSI,*) C
# (SENSI,*) C
# (RABIOT,*) C
# (VERETOUT,*) C
# (SORIANO,*) T
# (PAULOPEZ,*) Por
# (SIMEONE,*) Pc
# (LAPADULA,*) Pc
# (ANDRESILVA,*) Pc
# (ZAZA,*) Pc
# (DICARMINE,*) Pc
# (MATUIDI,*) M C
# (LULIC,*) E C
# (CASTAGNE,*) E
# (DEVRIJ,*) Dc
# (MANOLAS,*) Dc
# (CASTRO,*) C T
# (KRUNIC,*) C T
# (PELLEGRINILO,*) C T
# (FREULER,*) C
# (PALACIO,*) A
# (SANSONEN,*) A
# (CAPRARI,*) A
# (GABBIADINI,*) A
# (PUSSETTO,*) W A
# (DIFRANCESCOF,*) W
# (CALHANOGLU,*) T
# (TORREGROSSA,*) Pc
# (CAICEDO,*) Pc
# (SCHICK,*) Pc
# (DEROON,*) M C
# (BENNACER,*) M C
# (LOCATELLIM,*) M C
# (FOFANA,*) M C
# (NANDEZ,*) M C
# (GHOULAM,*) Ds E
# (DANILO,*) Dd Ds E
# (DAMBROSIO,*) Dd Ds Dc
# (BROZOVIC,*) C
# (KESSIE,*) C
# (KARAMOH,*) A
# (PANDEV,*) T A
# (SAPONARA,*) T
# (CRAGNO,*) Por
# (AUDERO,*) Por
# (SANTANDER,*) Pc
# (OBIANG,*) M C
# (ASAMOAH,*) Ds E
# (DILORENZO,*) Dd E
# (LIROLA,*) Dd E
# (MILENKOVIC,*) Dd Dc
# (BONUCCI,*) Dc
# (MALINOVSKYI,*) C T
# (TRAOREHJ,*) C T
# (LINETTY,*) C
# (CASTILLEJO,*) W A
# (PASTORE,*) T
# (BARAK,*) T
# (DRAGOWSKI,*) Por
# (CONSIGLI,*) Por
# (MUSSO,*) Por
# (NESTOROVSKI,*) Pc
# (POLI,*) M C
# (BISOLI,*) M C
# (LUCASLEIVA,*) M C
# (DUNCAN,*) M C
# (MEITE,*) M C
# (RINCON,*) M
# (CANDREVA,*) E W
# (BIRAGHI,*) Ds E
# (FLORENZI,*) Dd E
# (DESILVESTRI,*) Dd E
# (TOLOI,*) Dc
# (BASELLI,*) C T
# (ROG,*) C
# (SCHONE,*) C
# (FARIAS,*) A
# (RAMIREZ,*) T
# (SKORUPSKI,*) Por
# (SANABRIA,*) Pc
# (LAMANTIA,*) Pc
# (PAZZINI,*) Pc
# (GAGLIARDINI,*) M C
# (VECINO,*) M C
# (BIGLIA,*) M C
# (DIAWARA,*) M C
# (MANDRAGORA,*) M C
# (CUADRADO,*) E W
# (ROMULO,*) E M
# (LAZARO,*) E
# (CALABRIA,*) Dd E
# (ZAPPACOSTA,*) Dd E
# (PALOMINO,*) Dc
# (PEZZELLAGER,*) Dc
# (ROMEROC,*) Dc
# (VAVRO,*) Dc
# (BRUNOALVES,*) Dc
# (FERRARIG,*) Dc
# (BONIFAZI,*) Dc
# (RODRIGOBECAO,*) Dc
# (DUARTE,*) Dc
# (PASALIC,*) C T
# (ZACCAGNI,*) C T
# (CRISTANTE,*) C
# (JANKTO,*) C
# (SKOVOLSEN,*) A
# (YOUNES,*) W A
# (SILIGARDI,*) W
# (BERENGUER,*) W
# (MOROSINI,*) T A
# (SPALEK,*) T
# (MANCOSU,*) T
# (SEPE,*) Por
# (BERISHAE,*) Por
# (BARROW,*) Pc
# (PALOSCHI,*) Pc
# (TEODORCZYK,*) Pc
# (TONALI,*) M C
# (EKDAL,*) M C
# (MURGIA,*) M C
# (LAZOVIC,*) E W
# (AINA,*) E
# (DIJKS,*) Ds E
# (HERNANDEZT,*) Ds E
# (RODRIGUEZR,*) Ds E
# (MURRU,*) Ds E
# (DENSWIL,*) Ds Dc
# (RADU,*) Ds Dc
# (GAGLIOLO,*) Ds Dc
# (IGOR,*) Ds Dc
# (DJIDJI,*) Ds Dc
# (SAMIR,*) Ds Dc
# (MALCUIT,*) Dd E
# (CACCIATORE,*) Dd Ds E
# (TOLJAN,*) Dd Ds E
# (STRYGERLARSEN,*) Dd Dc E
# (CISTANA,*) Dd Dc
# (BIRASCHI,*) Dd Dc
# (DJIMSITI,*) Dc
# (DANILOLAR,*) Dc
# (ZAPATAC,*) Dc
# (DEMIRAL,*) Dc
# (LUIZFELIPE,*) Dc
# (FAZIO,*) Dc
# (MURILLO,*) Dc
# (LYANCO,*) Dc
# (SKRTEL,*) Dc
# (ZMRHAL,*) C W
# (DZEMAILI,*) C T
# (IONITA,*) C T
# (CASTROVILLI,*) C T
# (BESSA,*) C T
# (KHEDIRA,*) C
# (ADEKANYE,*) A
# (BIRSA,*) T
# (MARONI,*) T
# (JORONEN,*) Por
# (RADUI,*) Por
# (SILVESTRI,*) Por
# (AYE,*) Pc
# (CORNELIUS,*) Pc
# (FLOCCARI,*) Pc
# (CIGARINI,*) M C
# (LERAGER,*) M C
# (HERNANI,*) M C
# (MISSIROLI,*) M C
# (MIGUELVELOSO,*) M C
# (RADOVANOVIC,*) M
# (WALACE,*) M
# (JONY,*) E W
# (DALESSANDRO,*) E
# (FARES,*) E
# (SPINAZZOLA,*) Ds E
# (ROGERIO,*) Ds E
# (BOCCHETTI,*) Ds Dc
# (LAURINI,*) Dd E
# (HYSAJ,*) Dd Ds E
# (MASIELLOA,*) Dd Dc
# (CEPPITELLI,*) Dc
# (RUGANI,*) Dc
# (MUSACCHIO,*) Dc
# (COLLEY,*) Dc
# (CIONEK,*) Dc
# (VICARI,*) Dc
# (ELMAS,*) C T
# (NDOJ,*) C
# (BENTANCUR,*) C
# (BARILLA,*) C
# (GRASSI,*) C
# (SPROCATI,*) W A
# (GABRIEL,*) Por
# (STURARO,*) M C
# (BADELJ,*) M C
# (CATALDI,*) M C
# (BADU,*) M C
# (AMRABAT,*) E M
# (MARTELLA,*) Ds E
# (BARRECA,*) Ds E
# (PELLEGRINILU,*) Ds E
# (CALDERONI,*) Ds E
# (SABELLI,*) Dd E
# (BENZAR,*) Dd E
# (BERESZYNSKI,*) Dd E
# (DEPAOLI,*) Dd E
# (MBAYE,*) Dd Ds E
# (MATEJU,*) Dd Ds E
# (MATTIELLO,*) Dd Ds E
# (RRAHMANI,*) Dd Ds Dc
# (CECCHERINI,*) Dd Dc
# (GRAVILLON,*) Dd Dc
# (CHANCELLOR,*) Dc
# (KLAVAN,*) Dc
# (MAGNANI,*) Dc
# (MARLON,*) Dc
# (FELIPE,*) Dc
# (DEMAIO,*) Dc
# (TROOSTEKONG,*) Dc
# (VERRE,*) C T
# (VALOTI,*) C T
# (ZURKOWSKI,*) C
# (LUKIC,*) C
# (GUMUS,*) A
# (BORINI,*) W
# (FALCINELLI,*) Pc
# (BONAZZOLI,*) Pc
# (MONCINI,*) Pc
# (SHAKHOV,*) M C
# (BARRETO,*) M C
# (JAJALO,*) M C
# (BRUGMAN,*) M C
# (TACHTSIDIS,*) M
# (MAGNANELLI,*) M
# (DESSENA,*) E M
# (MARUSIC,*) E
# (LAXALT,*) E
# (SEMA,*) E
# (PAJAC,*) Ds E
# (MARIORUI,*) Ds E
# (PEZZELLAGIU,*) Ds E
# (JUANJESUS,*) Ds Dc
# (DELLORCO,*) Ds Dc
# (CONTI,*) Dd E
# (RISPOLI,*) Dd E
# (VENUTI,*) Dd Ds E
# (DESCIGLIO,*) Dd Ds E
# (PISACANE,*) Dd Ds Dc
# (TOMIYASU,*) Dd Dc
# (ROSSETTINI,*) Dd Dc
# (MAKSIMOVIC,*) Dd Dc
# (IACOPONI,*) Dd Dc
# (ROMAGNA,*) Dc
# (BASTOS,*) Dc
# (LUCIONI,*) Dc
# (TONELLI,*) Dc
# (DAWIDOWICZ,*) Dc
# (GUNTER,*) Dc
# (CETIN,*) Dc
# (LERIS,*) C W
# (BERISHAV,*) C T
# (MAJER,*) C T
# (HILJEMARK,*) C
# (PETRICCIONE,*) C
# (THORSBY,*) C
# (BOURABIA,*) C
# (FALCO,*) A
# (EYSSERIC,*) W T
# (DIGAUDIO,*) W
# (DJURICIC,*) T
# (BUFFON,*) Por
# (MATRI,*) Pc
# (BRADARIC,*) M C
# (SCOZZARELLA,*) M C
# (GONALONS,*) M C
# (VIEIRA,*) M C
# (VIVIANI,*) M C
# (FARAGO,*) E C
# (LYKOGIANNIS,*) Ds E
# (AUGELLO,*) Ds E
# (VITALEL,*) Ds E
# (EMPEREUR,*) Ds Dc
# (GHIGLIONE,*) Dd E
# (SALA,*) Dd E
# (TERAVEST,*) Dd E
# (FARAONI,*) Dd E
# (FERRARIA,*) Dd Dc
# (MULDUR,*) Dd Dc
# (TOMOVIC,*) Dd Dc
# (BANI,*) Dc
# (BASTONI,*) Dc
# (MECCARIELLO,*) Dc
# (CALDARA,*) Dc
# (CHIRICHES,*) Dc
# (DERMAKU,*) Dc
# (CHABOT,*) Dc
# (GOLDANIGA,*) Dc
# (BREMER,*) Dc
# (NUYTINCK,*) Dc
# (SCHOUTEN,*) C T
# (KULUSEVSKI,*) C T
# (JAGIELLO,*) C
# (HENDERSONL,*) C
# (AGUDELO,*) C
# (SOTTIL,*) A
# (PJACA,*) A
# (JANKOVIC,*) W T
# (OSPINA,*) Por
# (CERRI,*) Pc
# (HAN,*) Pc
# (VLAHOVIC,*) Pc
# (FAVILLI,*) Pc
# (CERAVOLO,*) Pc
# (CRISTOFORO,*) M C
# (DABO,*) M C
# (CAPEZZI,*) M C
# (OLIVA,*) M
# (LUKAKUJ,*) E
# (RECA,*) Ds E
# (DALBERT,*) Ds E
# (DIMARCO,*) Ds E
# (LUPERTO,*) Ds Dc
# (PELUSO,*) Ds Dc
# (ADJAPONG,*) Dd E
# (DICKMANN,*) Dd E
# (SANTON,*) Dd Ds E
# (WALUKIEWICZ,*) Dc
# (RANOCCHIA,*) Dc
# (WALLACE,*) Dc
# (SALAMON,*) Dc
# (KINGSLEY,*) C T
# (HAYE,*) C T
# (TABANELLI,*) C T
# (GUSTAFSON,*) C T
# (PESSINA,*) C
# (SVANBERG,*) C
# (BORJAVALERO,*) C
# (BRIGNOLA,*) A
# (EDERA,*) A
# (RAGUSA,*) A
# (PARIGINI,*) W
# (LOFASO,*) T A
# (ANDERSONA,*) T
# (RAFAEL,*) Por
# (SANDRO,*) M C
# (DANZI,*) M C
# (KREJCI,*) E
# (CURCIO,*) Ds E
# (DURMISI,*) Ds E
# (VERA,*) Ds E
# (STRINIC,*) Ds E
# (TRIPALDELLI,*) Ds E
# (REGINI,*) Ds Dc E
# (PINNA,*) Dd E
# (FIAMOZZI,*) Dd E
# (SEMPRINI,*) Dd Dc E
# (PATRIC,*) Dd Dc E
# (SIERRALTA,*) Dd Dc
# (IBANEZ,*) Dc
# (GASTALDELLO,*) Dc
# (RASMUSSEN,*) Dc
# (ELYAMIQ,*) Dc
# (OPOKU,*) Dc
# (KUMBULLA,*) Dc
# (DEIOLA,*) C
# (RIGONIL,*) C
# (MAZZITELLI,*) C
# (VALDIFIORI,*) C
# (DESPODOV,*) A
# (RAGATZU,*) A
# (TUTINO,*) A
# (ANTONUCCI,*) A
# (CICIRETTI,*) W T
# (MONTIEL,*) T A
# (TREMOLADA,*) T
# (FAGIOLI,*) T
# (GAETANO,*) T
# (ROSSIF,*) Por
# (SPORTIELLO,*) Por
# (DACOSTA,*) Por
# (SARRM,*) Por
# (ALFONSO,*) Por
# (ANDRENACCI,*) Por
# (ARESTI,*) Por
# (BRANCOLINI,*) Por
# (CEROFOLINI,*) Por
# (TERRACCIANO,*) Por
# (JANDREI,*) Por
# (MARCHETTI,*) Por
# (VODISEK,*) Por
# (BERNI,*) Por
# (PADELLI,*) Por
# (PERIN,*) Por
# (PINSOGLIO,*) Por
# (GUERRIERI,*) Por
# (PROTO,*) Por
# (BLEVE,*) Por
# (MILLI,*) Por
# (VIGORITO,*) Por
# (DONNARUMMAAN,*) Por
# (REINA,*) Por
# (KARNEZIS,*) Por
# (COLOMBI,*) Por
# (FUZATO,*) Por
# (MIRANTE,*) Por
# (OLSEN,*) Por
# (FALCONE,*) Por
# (PEGOLO,*) Por
# (THIAMD,*) Por
# (ROSATI,*) Por
# (ZACCAGNO,*) Por
# (NICOLAS,*) Por
# (PERISAN,*) Por
# (BERARDIA,*) Por
# (BORGHETTO,*) Por
# (RADUNOVIC,*) Por
# (ALASTRA,*) Por
# (RUSSOA,*) Por
# (LETICA,*) Por
# (AVOGADRI,*) Por
# (GEMELLO,*) Por
# (PICCOLI,*) Pc
# (ESPOSITOSE,*) Pc
# (SALCEDOE,*) Pc
# (ADORANTE,*) Pc
# (RASPADORI,*) Pc
# (RAUTI,*) Pc
# (TUPTA,*) Pc
# (VIVIANIM,*) M C
# (ROVELLA,*) M C
# (STREFEZZA,*) E W
# (TERZIC,*) Ds E
# (GALLO,*) Ds E
# (PAZ,*) Ds Dc
# (RANIERIL,*) Ds Dc
# (BOUAH,*) Dd E
# (GILLI,*) Dd E
# (CRESCENZI,*) Dd Ds E
# (OKOLI,*) Dc
# (CORBO,*) Dc
# (MANGRAVITI,*) Dc
# (RIZZON,*) Dc
# (JORGESILVA,*) Dc
# (RICCARDID,*) Dc
# (GABBIA,*) Dc
# (MINELLI,*) Dc
# (BIANDA,*) Dc
# (BUONGIORNO,*) Dc
# (CIPRIANO,*) Dc
# (COLLEYE,*) C W T
# (ZENNARO,*) C T
# (RICCARDI,*) C T
# (DEANGELIS,*) C T
# (CASSATA,*) C
# (AGOUME,*) C
# (NICOLUSSICAVIGLIA,*) C
# (PORTANOVA,*) C
# (LUCASFELIPPE,*) C
# (CAMBIAGHI,*) A
# (JUWARA,*) A
# (THEREAU,*) A
# (CANGIANO,*) A
# (BAHLOULI,*) A
# (MILLICO,*) A
# (MICIN,*) A
# ;

# %%
def initializeModules():
    modules={}
    m343=[]
    for i in range(3):
        m343.append(["Dc"])
    for i in range(2):
        m343.append(["E"])
    for i in range(2):
        m343.append(["W","A"])
    m343.append(["C"])
    m343.append(["M","C"])
    m343.append(["A","Pc"])
    modules["m343"]=m343
    
    
    m3412=[]
    for i in range(3):
        m3412.append(["Dc"])
    for i in range(2):
        m3412.append(["E"])
    for i in range(2):
        m3412.append(["Pc","A"])   
    m3412.append(["C"])
    m3412.append(["M","C"])
    m3412.append(["T"])
    modules["m3412"]=m3412  
    
    
    m3421=[]
    for i in range(3):
        m3421.append(["Dc"])  
    m3421.append(["M"])
    m3421.append(["M","C"])
    m3421.append(["E"])
    m3421.append(["T"])
    m3421.append(["E","W"])
    m3421.append(["Pc","A"])
    m3421.append(["T","A"])
    modules["m3421"]=m3421  
    
    m352=[]
    for i in range(3):
        m352.append(["Dc"])
    for i in range(2):
        m352.append(["A","Pc"])
    m352.append(["E","W"])
    m352.append(["M"])
    m352.append(["M","C"])
    m352.append(["E"])
    m352.append(["C"])
    modules["m352"]=m352  
    
    m3511=[]
    for i in range(3):
        m3511.append(["Dc"])
    for i in range(2):
        m3511.append(["M"])
    for i in range(2):
        m3511.append(["E","W"])
    m3511.append(["C"])
    m3511.append(["A","Pc"])
    m3511.append(["T","A"])
    modules["m3511"]=m3511  
    
    
    m433=[]
    for i in range(2):
        m433.append(["Dc"])
    for i in range(2):
        m433.append(["W","A"])
    m433.append(["Dd"])
    m433.append(["Ds"])
    m433.append(["C"])
    m433.append(["M"])
    m433.append(["C","M"])
    m433.append(["A","Pc"])
    modules["m433"]=m433
    
    m4312=[]
    for i in range(2):
        m4312.append(["Dc"])
    m4312.append(["Dd"])
    m4312.append(["Ds"])
    for i in range(2):
        m4312.append(["A","Pc"])
    m4312.append(["C"])
    m4312.append(["M"])
    m4312.append(["C","M"])
    m4312.append(["T"])
    modules["m4312"]=m4312
    
    m442=[]
    for i in range(2):
        m442.append(["Dc"])
    m442.append(["Dd"])
    m442.append(["Ds"])
    for i in range(2):
        m442.append(["A","Pc"])
    m442.append(["C"])
    m442.append(["E"])
    m442.append(["C","M"])
    m442.append(["E","W"])
    modules["m442"]=m442
    
    m4141=[]
    for i in range(2):
        m4141.append(["Dc"])
    m4141.append(["Dd"])
    m4141.append(["Ds"])
    for i in range(2):
        m4141.append(["C","T"])
    for i in range(2):
        m4141.append(["W"])
    m4141.append(["M"])
    m4141.append(["A","Pc"])
    modules["m4141"]=m4141
    
    m4411=[]
    for i in range(2):
        m4411.append(["Dc"])
    m4411.append(["Dd"])
    m4411.append(["Ds"])
    for i in range(2):
        m4411.append(["E","W"])
    m4411.append(["C"])
    m4411.append(["A","T"])
    m4411.append(["M"])
    m4411.append(["A","Pc"])
    modules["m4411"]=m4411
    
    m4231=[]
    for i in range(2):
        m4231.append(["Dc"])
    m4231.append(["Dd"])
    m4231.append(["Ds"])
    
    m4231.append(["M"])
    m4231.append(["M","C"])
    m4231.append(["W"])
    m4231.append(["T"])
    m4231.append(["A","Pc"])
    m4231.append(["W","A"])
    modules["m4231"]=m4231
    
    
    for key,mod in modules.items():
        mod.append(["Por"])
        mod+=mod
        
    uselessModules=["m3412","m3421","m352","m4312"]
    for uselessModule in uselessModules:
        del modules[uselessModule]
    
    return modules


def produceStringFromDictOfModules(dictOfModules):
    retString="set CompatibilitySlotRole:=\n"
    modString="set Modules:= "
    multiplierString="param :multiplier:=\n"
    
    for key,val in dictOfModules.items():
        numberOfSlot=1
        modString+=" {}".format(key)
        for slot in val:
            retString+="({},{},*) =".format(key,numberOfSlot)
            for role in slot:
                retString+=" {} ".format(role)
            retString+="\n"
            numberOfSlot+=1
        for i in range(11):
            multiplierString+="{} {} {}\n".format(key,i+12,probToPlay(4,5,0.1))
    retString+=";\n"
    retString+=modString
    retString+=";\n"
    retString+=multiplierString
    retString+=";\n"
    
    return retString;

# %%
def initializeMilp(playersDF):
    performanceString = "param:performance := \n"
    costString = "param :cost:= \n"
    playersString = "set Players:= "
    boughtParameterString= "param:alreadyBought:="
    roleSlotString="set CompatibilitySlotRole:= \n"
    
    
    probabilityOfFault=0.1
    
    cont=0
    slotPos=1
    
    for  index, player in playersDF.iterrows():
        if not player["bought"]:
            cont+=1
            performanceString+= "{} {}\n".format(player["name"],player["perf"])
            costString+= "{} {}\n".format(player["name"],player["cost"])
            boughtParameterString+= "{} {}\n".format(player["name"],player["bought"])
            playersString+= " {} ".format(player["name"])

    print("{} players available".format(cont))



    roleCompatibilityString=getPlayerRoleCompatibilityString()
    performanceString+= ";\n"
    costString+= ";\n"
    playersString+= ";\n"
    boughtParameterString+= ";\n"
    roleSlotString=produceStringFromDictOfModules(initializeModules())
    
    with open('dat-file-configuration-mantra.txt', 'r') as file:
        fixedHeader  =  file.read()
        with open('fantasy-auction-mantra.dat', 'w') as outputFile:
            #outputFile.write("param  budget:={};\n".format(BUDGET))
            outputFile.write(fixedHeader)
            outputFile.write(roleSlotString)
            #outputFile.write(multiplierString)
            outputFile.write(playersString)
            outputFile.write(roleCompatibilityString)
            outputFile.write(performanceString)
            #outputFile.write(costString)
            outputFile.write(boughtParameterString)

# %%
playerz["bought"]=0
playerz["name"]=playerz["Name"]
playerz["role"]=playerz["R"]
playerz["perf"]=playerz["MeanFantasyEvaluation"]
playerz["cost"]=0
BUDGET=500
initializeMilp(playerz)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-49a7bd2b26e7> in <module>()
#       1 playerz["bought"]=0
#       2 playerz["name"]=playerz["Name"]
# ----> 3 playerz["role"]=playerz["R"]
#       4 playerz["perf"]=playerz["MeanFantasyEvaluation"]
#       5 playerz["cost"]=0
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'R'
