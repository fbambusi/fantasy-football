# %%
import pandas as pd

# %%
from amplpy import AMPL,Environment
ampl = AMPL(Environment('/home/asino/Downloads/ampl_linux-intel64/'))
ampl.setOption("solver","/home/asino/Downloads/ampl_linux-intel64/cplex")
ampl.setOption("absmipgap",1)

# %%
ME="me"

# %%
def fillDictOfBrokenPlayers():
    bought=pd.read_csv("availability-of-players.csv")
    dictOfMyPlayers={}
    dictOfBrokenPlayers={}
    for idx,player in bought.iterrows():
        if player["Owner"]==ME:
            if player["CanPlay"]==0:
                dictOfBrokenPlayers[player["Name"]]=1
            else:
                dictOfBrokenPlayers[player["Name"]]=0
    return dictOfBrokenPlayers

dictOfBrokenPlayers=fillDictOfBrokenPlayers()
print(dictOfBrokenPlayers)
# Out:
# {'CRISCITO': 0, 'STRAKOSHA': 0, 'ZIELINSKI': 0, 'KURTIC': 0, 'ZAPATAD': 0, 'IZZO': 0, 'NKOULOU': 1, 'KOULIBALY': 0, 'POLITANO': 1, 'KESSIE': 0, 'BONIFAZI': 0, 'MURRU': 0, 'RADU': 0, 'QUAGLIARELLA': 0, 'VERETOUT': 0, 'GOMEZA': 0, 'BONUCCI': 0, 'BERISHAE': 0, 'FLORENZI': 0, 'MARTINEZL': 0, 'CHIELLINI': 0, 'MILENKOVIC': 0, 'SUSO': 0, 'MANDRAGORA': 0, 'NANDEZ': 0, 'IAGOFALQUE': 0, 'BALOTELLI': 0, 'PROTO': 0}

# %%
ampl.read("07-prepare-selection.mod")
ampl.readData("operations-mantra-online.dat")
# Out:
# Warning:
# 	07-prepare-selection.mod
# 	line 33 offset 991
# 	Caution: 0-dimensional slice

# %%
def suggestTeam(dictOfBrokenPlayers):
    plas=ampl.getSet("Players").getValues()
    valuesForBrokenPlayersAmpl={}
    for name in plas:
        name=name[0]
        #print(name)
        valuesForBrokenPlayersAmpl[name]=0
    for player,value in dictOfBrokenPlayers.items():
        valuesForBrokenPlayersAmpl[player]=value
    ampl.getParameter("broken").setValues(valuesForBrokenPlayersAmpl)
        
        
        
    
    ampl.solve()

# %%
def analyseSolution():
    putPlayerInSlot=ampl.getVariable("putPlayerInSlot")
    cost=ampl.getParameter("cost")
    pfs=ampl.getParameter("performance")
    moduleChosen=ampl.getVariable("bidderChoosesModule")
    globalPerf=ampl.getVariable("minPerf").value()
    
    roles=ampl.getSet("CompatibilityPlayerRole").getValues().toDict()
    slots=ampl.getSet("CompatibilitySlotRole").getValues().toDict()
    solution=putPlayerInSlot.getValues().toDict()
    costs=cost.getValues().toDict()
    pfs=pfs.getValues().toDict()
    modules=moduleChosen.getValues().toDict()
    moduleUsed="AAA"
    

    for moduleName,taken in modules.items():
        if taken>0.5:
            #print("Module: {}\n\n".format(moduleName))
            moduleUsed=moduleName
    myPls={}
    for key,val in solution.items():

        if key[0]==moduleUsed:
            if val>0.5:
                myPls[key[2]]=key[1]
                #print(key,val)
    rolesA={}

    #To show the roles of each player
    for key,val in roles.items():
        if key[0] not in rolesA.keys():
            rolesA[key[0]]=[]
        rolesA[key[0]].append(key[1])


    mappingSlotNumberToPossibleRoles={}
    for key,val in slots.items():
        if key[0]==moduleUsed:

            slotNr=key[1]
            role=key[2]
            if slotNr not in mappingSlotNumberToPossibleRoles.keys():
                mappingSlotNumberToPossibleRoles[slotNr]=[]
            mappingSlotNumberToPossibleRoles[slotNr].append(role)

    emptySlotsInField=0
    emptySlotsOutside=0
    message=""
    for slotNr,possibleRoles in mappingSlotNumberToPossibleRoles.items():
        if slotNr<=11:
            privilege="TOP"
        else:
            privilege="NO"
        try:
            message+=("{} plays  in slot {}  {}\n".format(myPls[slotNr], possibleRoles,privilege))
        except KeyError:
            if privilege=="TOP":
                emptySlotsInField+=1
            else:
                emptySlotsOutside+=1
    return globalPerf,moduleUsed,message,emptySlotsInField,emptySlotsOutside

# %%
pls=dictOfBrokenPlayers.keys()
dictOfEffects={}
solidPlayers=["STRAKOSHA","BERISHAE","IZZO"]
for player in pls:
    for p2 in pls:
        if player >p2:
            if player not in solidPlayers and p2 not in solidPlayers:
                broks=fillDictOfBrokenPlayers()
                broks[player]=1
                broks[p2]=1
                suggestTeam(broks)
                dictOfEffects[(player,p2)]=(analyseSolution())
#suggestTeam({},{})
# Out:
# CPLEX 12.8.0.0: optimal integer solution; objective 84.16829957
# 1418 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.01535457
# 1215 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.32151607
# 1795 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.32151607
# 1552 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.06465088
# 1434 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.00279422
# 1388 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.43252558
# 1988 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.52360512
# 1527 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.26920628
# 1360 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.52360512
# 1527 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.40858369
# 1701 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.43373023
# 1590 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.45780878
# 1593 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.06655512
# 1440 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.7826982
# 1689 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.88674158
# 1624 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.15366724
# 1693 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.28078523
# 1516 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.86754562
# 1811 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.30164239
# 1551 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.58694673
# 1591 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.65894312
# 1775 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81.35544036
# 1500 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.01998922
# 1500 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.52360512
# 1406 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.52360512
# 1536 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.52360512
# 1662 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.52360512
# 1544 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.93114033
# 1425 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.13569573
# 1178 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.35121527
# 1631 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.30021967
# 1641 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.02015668
# 1762 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.14727467
# 1613 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.73403507
# 1652 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.45343617
# 1570 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.39009457
# 1619 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.39009457
# 1600 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.35189204
# 1465 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.29901503
# 1634 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.08496793
# 2011 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.15847099
# 1392 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.08496793
# 2011 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.78094663
# 1720 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.04415243
# 1683 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.74504993
# 1658 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.08496793
# 1756 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81.83978802
# 2008 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.25910453
# 1876 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.44199915
# 1789 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.89120743
# 1666 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.75681033
# 1879 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.64104247
# 1624 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.08496793
# 1785 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.54820783
# 1825 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81.6715955
# 1203 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.31621003
# 1530 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.31621003
# 1751 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.09424729
# 1616 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.08496793
# 2079 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.08496793
# 1644 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.32151607
# 1583 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.39009457
# 1651 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.12809502
# 1510 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.87202617
# 1412 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.01377646
# 1662 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.71467396
# 1829 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.03735168
# 1616 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.86083146
# 1645 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.72643436
# 1657 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.18532684
# 1981 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.05459196
# 2002 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.51783186
# 1693 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1639 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1476 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1444 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1331 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.00377562
# 1588 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.61762733
# 1597 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.97487852
# 1716 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82
MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.00736417
# 1649 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.36461536
# 1560 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.17268968
# 1753 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.21167036
# 1633 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.86177236
# 1446 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.51783186
# 1575 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.51783186
# 1659 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.54262757
# 1360 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.54262757
# 1458 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.51783186
# 1650 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81.90814363
# 1497 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.22192981
# 1540 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.64121953
# 1292 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81.71472258
# 1594 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.64121953
# 1295 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81.70386141
# 1641 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.60040403
# 1228 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.30130153
# 1133 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.64121953
# 1748 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.02176812
# 1129 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 81.86918692
# 1564 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.44745903
# 1455 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.31306192
# 1130 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.64121953
# 1374 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.64121953
# 1434 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.10445942
# 1336 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.23912481
# 1134 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.23912481
# 1000 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.23912481
# 1159 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.64121953
# 1283 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.64121953
# 1361 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.94833533
# 1095 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.88647866
# 1322 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.15289073
# 1491 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.36841027
# 1500 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.31741467
# 1300 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.03735168
# 1431 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.16446967
# 1460 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.75123007
# 1080 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.47063117
# 1230 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1437 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1371 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.00970198
# 1310 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.39009457
# 1476 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.15289073
# 1393 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.87202617
# 1547 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.31741467
# 1368 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.40285987
# 1586 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.03735168
# 1343 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.16446967
# 1499 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.75123007
# 1575 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.18532684
# 1755 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.47063117
# 1661 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.54262757
# 1559 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1072 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1459 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1388 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 82.94833533
# 1448 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.31741467
# 1389 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.81538895
# 1113 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.16446967
# 1518 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 83.75123007
# 1462 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.47063117
# 1849 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1712 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.32151607
# 1844 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.39009457
# 1671 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1593 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.12809502
# 1676 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1764 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.87202617
# 1591 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.01377646
# 1673 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.71467396
# 1499 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.03735168
# 1508 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.86083146
# 1641 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.72643436
# 1444 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.18532684
# 1766 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.05459196
# 1533 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 84.51783186
# 1714 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1450 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1511 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1747 MIP simplex iterations
# 0 branch-and-bound nodes
# CPLEX 12.8.0.0: optimal integer solution; objective 85.40728957
# 1889 MIP simplex iterations
# 0 branch-and-bound nodes

# %%
couples=dictOfEffects.keys()
cp=sorted(couples,key=lambda k:dictOfEffects[k][0])
for i in range(10):
    print(cp[i],dictOfEffects[cp[i]][0])
    print(dictOfEffects[cp[i]][2])
    break
# Out:
# ('ZIELINSKI', 'SUSO') 81.35544035851579
# KOULIBALY plays  in slot ['Dc']  TOPBONUCCI plays  in slot ['Dc']  TOPIZZO plays  in slot ['Dd']  TOPMURRU plays  in slot ['Ds']  TOPQUAGLIARELLA plays  in slot ['A', 'Pc']  TOPZAPATAD plays  in slot ['A', 'Pc']  TOPVERETOUT plays  in slot ['C']  TOPFLORENZI plays  in slot ['E']  TOPKESSIE plays  in slot ['C', 'M']  TOPCRISCITO plays  in slot ['E', 'W']  TOPSTRAKOSHA plays  in slot ['Por']  TOPCHIELLINI plays  in slot ['Dc']  NOBONIFAZI plays  in slot ['Dc']  NOMILENKOVIC plays  in slot ['Dd']  NORADU plays  in slot ['Ds']  NOGOMEZA plays  in slot ['A', 'Pc']  NOMARTINEZL plays  in slot ['A', 'Pc']  NOMANDRAGORA plays  in slot ['C']  NOKURTIC plays  in slot ['C', 'M']  NOBERISHAE plays  in slot ['Por']  NO
